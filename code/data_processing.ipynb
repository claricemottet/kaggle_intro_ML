# %%
#import libraries

import pandas as pd
import kagglehub
import os

# %%
#establish path to kaggle data

# Download latest version
path = kagglehub.dataset_download("dansbecker/melbourne-housing-snapshot")

print(os.listdir(path))
# Out:
# ['melb_data.csv']

# %%
#import in melbourne data

melbourne_file_path = path+'/melb_data.csv'

df_mel = pd.read_csv(melbourne_file_path, dtype=str)

# %%
df_mel.describe()
# Out:
#            Suburb           Address  Rooms   Type      Price Method SellerG  \
# count       13580             13580  13580  13580      13580  13580   13580
# unique        314             13378      9      3       2204      5     268
# top     Reservoir  36 Aberfeldie St      3      h  1100000.0      S  Nelson
# freq          359                 3   5881   9449        113   9022    1565
#
#               Date Distance Postcode  ... Bathroom    Car Landsize  \
# count        13580    13580    13580  ...    13580  13518    13580
# unique          58      202      198  ...        9     11     1448
# top     27/05/2017     11.2   3073.0  ...      1.0    2.0      0.0
# freq           473      739      359  ...     7512   5591     1939
#
#        BuildingArea YearBuilt CouncilArea Lattitude Longtitude  \
# count          7130      8205       12211     13580      13580
# unique          602       144          33      6503       7063
# top           120.0    1970.0    Moreland  -37.8361   144.9966
# freq            114       866        1163        21         17
#
#                    Regionname Propertycount
# count                   13580         13580
# unique                      8           311
# top     Southern Metropolitan       21650.0
# freq                     4695           359
#
# [4 rows x 21 columns]
