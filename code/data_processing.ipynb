# %%
#import libraries

import pandas as pd
import kagglehub
import os

pd.set_option("display.max_columns", None)

# %%
#establish path to kaggle data

# Download latest version
path = kagglehub.dataset_download("dansbecker/melbourne-housing-snapshot")

print(os.listdir(path))
# Out:
# ['melb_data.csv']

# %%
#import in melbourne data

melbourne_file_path = path+'/melb_data.csv'

df_mel = pd.read_csv(melbourne_file_path, dtype=str)

# %%
df_mel.columns = df_mel.columns.str.lower()
df_mel.columns

#postcode is corrupted because it appears as a number
#there are nulls in the buildingarea, yearbuilt

list_nums = ['rooms', 'price', 'distance', 'postcode', 'bedroom2', 'bathroom', 'car',
       'landsize', 'buildingarea', 'yearbuilt',  'lattitude',
       'longtitude','propertycount']
list_dates = ['date']

df_mel[list_nums] = pd.to_numeric(df_mel[list_nums])
df_mel[list_dates] = pd.to_datetime(df_mel[list_dates])

df_mel.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 12
#       7 list_nums = ['rooms', 'price', 'distance', 'postcode', 'bedroom2', 'bathroom', 'car',
#       8        'landsize', 'buildingarea', 'yearbuilt',  'lattitude',
#       9        'longtitude','propertycount']
#      10 list_dates = ['date']
# ---> 12 df_mel[list_nums] = pd.to_numeric(df_mel[list_nums])
#      13 df_mel[list_dates] = pd.to_datetime(df_mel[list_dates])
#      15 df_mel.head()
#
# File ~/.pyenv/versions/base_env/lib/python3.12/site-packages/pandas/core/tools/numeric.py:206, in to_numeric(arg, errors, downcast, dtype_backend)
#     204     values = np.array([arg], dtype="O")
#     205 elif getattr(arg, "ndim", 1) > 1:
# --> 206     raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     207 else:
#     208     values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series
